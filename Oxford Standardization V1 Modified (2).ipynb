# %% [markdown]
# # Process walkthrough:
# - Access an excel file through user defined path
# - Loop through each sheet to look for unique identifiers like 'Group Name:' to identify Oxford Plans of the Table 1 format using condition given in the `collecting tables` function
# - Once Table 1 format is detected, check if there are multiple tables present in the sheet.
# - If there are more than one table in a sheet, use the `separate_table` function to separate the tables and store them individually in a list
# - If there is only 1 table in the sheet, again, store it in the same list
# - Loop over each table in the list and clean the data
# - Once cleaned, concatenate the clean dfs into a final df

# %% [markdown]
# ## Separating tables and Collecting them individually

# %%
import pandas as pd

#function to separate tables in case of multiple tables in a sheet

def separate_tables(df, df_list):
    # Convert all columns to string type
    df = df.astype(str)
    
    # Check if 'Group Name:' row exists in the DataFrame
    if df.apply(lambda x: x.str.contains('Group Name:')).any().any():
        # Find the row index where 'Group Name:' is present
        header_index = (df.apply(lambda x: x.str.contains('Group Name:')).any(axis=1)).idxmax()

        # Split the DataFrame into df1 and df2 based on the 'Group Name:' row
        df1 = df.iloc[:header_index]
        df2 = df.iloc[header_index + 1:]

        # Set the header of df2 using the 'Group Name:' row
        df2.columns = df.iloc[header_index]

        # Reset index for both DataFrames
        df1 = df1.reset_index(drop=True)
        df2 = df2.reset_index(drop=True)

        df_list.append(df1)
        df_list.append(df2)
        
    

#function to extract tables individually and store them in a list

def collecting_tables(file_path):
    # Read the Excel file
    xls = pd.ExcelFile(file_path)
    
    # Initialize an empty list to store dataframes
    table_list = []
    
    # Iterate through each sheet
    for sheet_name in xls.sheet_names:
        # Read the sheet into a DataFrame
        df = pd.read_excel(file_path, header=None, sheet_name=sheet_name)
        
        # Check if "Group Name:" exists in the top-left cells
        if "Group Name:" in df.iloc[:5, :5].values:
            df = df.T
            df.columns = df.iloc[0]
            df = df[1:]
            df.dropna(axis=0, how='all', inplace=True)
            df.reset_index(inplace=True, drop=True)
            
            df=df.astype(str)
            
            
            
            if (df.applymap(lambda x: 'Group Name:' in x)).any(axis=1).any():
                separate_tables(df, table_list)
            

                for table in table_list:
                    separate_tables(table, table_list)
                table_list = [item for item in table_list if not item.apply(lambda x: x.str.contains('Group Name:')).any().any()]
                
            else:
                table_list.append(df)
            
            
        else:
            pass
    
    
    return table_list

# %%
table_list=collecting_tables(r"C:\Users\shres\Downloads\multi table oxford sheet.xlsx")
# Out:
# C:\Users\shres\AppData\Local\Temp\ipykernel_36028\4097615813.py:45: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if "Group Name:" in df.iloc[:5, :5].values:

# %%
len(table_list)
# Out:
# 11

# %%
table_list[5]
# Out:
# 0                           NaN Group Name: Group Number(or TBD)  \
# 0    New benefits- Scroll right  Tienam Inc               554556
# 1                           nan         nan                  nan
# 2                           nan         nan                  nan
# 3                           nan         nan                  nan
# 4                           nan         nan                  nan
# 5                           nan         nan                  nan
# 6  INC2197031 Updated in yellow         nan                  nan
# 7              INC567870 8/9/21         nan                  nan
#
# 0        Request Date: Effective Date or NSB:  \
# 0  2020-04-02 00:00:00    2020-01-03 00:00:00
# 1                  nan                    nan
# 2                  nan                    nan
# 3                  nan                    nan
# 4                  nan                    nan
# 5                  nan                    nan
# 6                  nan                    nan
# 7                  nan                    nan
#
# 0 Please Note: All items listed on this form are subject to review  NaN  \
# 0                                                nan                nan
# 1                                                nan                nan
# 2                                                nan                nan
# 3                                                nan                nan
# 4                                                nan                nan
# 5                                                nan                nan
# 6                                                nan                nan
# 7                                                nan                nan
#
# 0                          NaN              General Information  \
# 0  Benefits Currently in Place  Current Plan 1: P0145445 BUY UP
# 1                          nan  Current Plan 2: P0145445 BUY UP
# 2                          nan  Current Plan 3: P0145445 BUY UP
# 3           Requested Benefits  Current Plan 1: P0145445 BUY UP
# 4                          nan  Current Plan 2: P0145445 BUY UP
# 5                          nan  Current Plan 3: P0145445 BUY UP
# 6                          nan                              nan
# 7                          nan                              nan
#
# 0               CSP Base (Similar standard plan) Tracking ID  \
# 0  Freedom HMO 2323                                      nan
# 1  Freedom HMO 2324                                      nan
# 2  Freedom HMO 2325                                      nan
# 3  Freedom HMO 2326                     KACTOHP58- MNS000025
# 4  Freedom HMO 2327                     KACTOHP58- MNS000026
# 5  Freedom HMO 2328                     KACTOHP58- MNS000027
# 6               nan                                      nan
# 7               nan                                      nan
#
# 0 No of Employees Enrolled: Group State (NY,NJ,CT) Market (Large or Small)  \
# 0                        23                     NJ                   Large
# 1                        25                     NJ                   Large
# 2                        45                     NJ                   Large
# 3                        36                     NJ                   Large
# 4                        26                     NJ                   Large
# 5                        15                     NJ                   Large
# 6                       nan                    nan                     nan
# 7                       nan                    nan                     nan
#
# 0 Product     Access  Network In Network (IN) PCP/Specialist OV Copay  \
# 0     HMO  Non Gated  Freedom             nan                   30/45
# 1     HMO  Non Gated  Freedom             nan                   30/50
# 2     HMO  Non Gated  Freedom             nan                     0/0
# 3     HMO  Non Gated  Freedom             nan                   30/55
# 4     HMO  Non Gated  Freedom             nan                   30/60
# 5     HMO  Non Gated  Freedom             nan                     0/1
# 6     nan        nan      nan             nan                     nan
# 7     nan        nan      nan             nan                     nan
#
# 0 ER Cost Share                           Hospital Cost Share   \
# 0           150  IP: 0 after deductible OP: 0 after deductible
# 1           160  IP: 0 after deductible OP: 0 after deductible
# 2           nan  IP: 0 after deductible OP: 0 after deductible
# 3           nan  IP: 0 after deductible OP: 0 after deductible
# 4           nan  IP: 0 after deductible OP: 0 after deductible
# 5           nan  IP: 0 after deductible OP: 0 after deductible
# 6           nan                                            nan
# 7           nan                                            nan
#
# 0 For Direct, EPO or Value Option Products IN Deductible IN Coinsurance %  \
# 0                                      nan     2500/5000              100
# 1                                      nan     2500/5000               90
# 2                                      nan     2500/5001               91
# 3                                      nan     2500/5002               92
# 4                                      nan     2500/5003               93
# 5                                      nan     2500/5004               94
# 6                                      nan           nan              nan
# 7                                      nan           nan              nan
#
# 0 IN Coinsurance Limit IN Out of Pocket Maximum Out of Network (OON):  \
# 0            3000/6000                3000/6001                   nan
# 1          32000/50000              32000/50000                   nan
# 2          32000/50001              32000/50001                   nan
# 3          32000/50002              32000/50002                   nan
# 4          32000/50003              32000/50003                   nan
# 5          32000/50004              32000/50004                   nan
# 6                  nan                      nan                   nan
# 7                  nan                      nan                   nan
#
# 0 OON Deductible OON Coinsurance % OON Coinsurance Limit  \
# 0      2500/5002                92           32000/50002
# 1      2500/5003                93           32000/50003
# 2      2500/5004                94           32000/50004
# 3      2500/5002                92           32000/50002
# 4      2500/5003                93           32000/50003
# 5      2500/5004                94           32000/50004
# 6            nan               nan                   nan
# 7            nan               nan                   nan
#
# 0 OON Out of Pocket Maximum Rx Copays (OV/Spec Copay must be listed above)  \
# 0               32000/50002                                       10/25/50
# 1               32000/50003                                            nan
# 2               32000/50004                                            nan
# 3               32000/50002                                       10/25/50
# 4               32000/50003                                            nan
# 5               32000/50004                                            nan
# 6                       nan                                            nan
# 7                       nan                                            nan
#
# 0 Rx Deductible- all drugs or brand only Rx PLAN   \
# 0                                    nan      nan
# 1                                    nan      nan
# 2                                    nan      nan
# 3                                    nan      nan
# 4                                    nan      nan
# 5                                    nan      nan
# 6                                    nan      nan
# 7                                    nan      nan
#
# 0 List all three parts of the benefit: visit or dollar limit, INN cost share and OON cost share
# 0                                                nan
# 1                                                nan
# 2                                                nan
# 3                              All radiology at 100%
# 4                                                nan
# 5                                                nan
# 6                                                nan
# 7                                                nan

# %% [markdown]
# ## Cleaning the data

# %%
import pandas as pd
import numpy as np

def clean_data(df_list):
    dfs = []
    
    for df in df_list:
        # Replace 'nan' strings with actual NaN values
        df.replace('nan', np.nan, inplace=True)
        
        # Find the index of 'Group Name:' column
        group_name_index = df.columns.get_loc('Group Name:')
        
        # Remove columns before 'Group Name:' column
        df = df.iloc[:, group_name_index:]
        
        # Fill missing values in specific columns
        columns_to_fill = ['Group Name:', 'Group Number(or TBD)', 'Request Date:', 'Effective Date or NSB:']
        for col in columns_to_fill:
            df[col].fillna(df[col].iloc[0], inplace=True)
        
        # Rename columns to strings
        df.columns = [str(column) for column in df.columns]
        
        # Iterate through each column to check for 'Requested Benefits' in string columns
        for column in df.select_dtypes(include='object').columns:
            if any(df[column].apply(lambda x: 'Requested Benefits' in str(x))):
                df.rename(columns={column: 'Benefits Status'}, inplace=True)

        # Fill missing values in 'Benefits Status' column with forward fill
        if 'Benefits Status' in df.columns:
            df['Benefits Status'] = df['Benefits Status'].fillna(method='ffill')

        # Rename 'General Information' column to 'Plan Information'
        df.rename(columns={'General Information': 'Plan Information'}, inplace=True)
        
        # Remove columns where all values are null
        df = df.dropna(axis=1, how='all')
        
        # Set display option to show all columns
        pd.set_option('display.max_columns', None)
        
        dfs.append(df.reset_index(drop=True))  # Reset index of each DataFrame
        
    return dfs

# Example usage:
clean_dfs = clean_data(table_list)

# %%
len(clean_dfs)
# Out:
# 11

# %% [markdown]
# ### This is how each df looks like now

# %%
clean_dfs[8]
# Out:
#   Group Name: Group Number(or TBD)        Request Date:  \
# 0     XYZ Inc               554556  2020-04-02 00:00:00
# 1     XYZ Inc               554556  2020-04-02 00:00:00
# 2     XYZ Inc               554556  2020-04-02 00:00:00
# 3     XYZ Inc               554556  2020-04-02 00:00:00
# 4     XYZ Inc               554556  2020-04-02 00:00:00
# 5     XYZ Inc               554556  2020-04-02 00:00:00
#
#   Effective Date or NSB:              Benefits Status  \
# 0    2020-01-03 00:00:00  Benefits Currently in Place
# 1    2020-01-03 00:00:00  Benefits Currently in Place
# 2    2020-01-03 00:00:00  Benefits Currently in Place
# 3    2020-01-03 00:00:00           Requested Benefits
# 4    2020-01-03 00:00:00           Requested Benefits
# 5    2020-01-03 00:00:00           Requested Benefits
#
#                   Plan Information               CSP  \
# 0  Current Plan 1: P0145445 BUY UP  Freedom HMO 2323
# 1  Current Plan 2: P0145445 BUY UP  Freedom HMO 2324
# 2  Current Plan 3: P0145445 BUY UP  Freedom HMO 2325
# 3  Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 4  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 5  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
#
#   Base (Similar standard plan) Tracking ID No of Employees Enrolled:  \
# 0                                      NaN                        23
# 1                                      NaN                        25
# 2                                      NaN                        45
# 3                     KACTOHP58- MNS000025                        36
# 4                     KACTOHP58- MNS000026                        26
# 5                     KACTOHP58- MNS000027                        15
#
#   Group State (NY,NJ,CT) Market (Large or Small) Product     Access  Network  \
# 0                     NJ                   Large     HMO  Non Gated  Freedom
# 1                     NJ                   Large     HMO  Non Gated  Freedom
# 2                     NJ                   Large     HMO  Non Gated  Freedom
# 3                     NJ                   Large     HMO  Non Gated  Freedom
# 4                     NJ                   Large     HMO  Non Gated  Freedom
# 5                     NJ                   Large     HMO  Non Gated  Freedom
#
#   PCP/Specialist OV Copay ER Cost Share  \
# 0                   30/45           150
# 1                   30/50           160
# 2                     0/0           NaN
# 3                   30/55           NaN
# 4                   30/60           NaN
# 5                     0/1           NaN
#
#                             Hospital Cost Share  IN Deductible  \
# 0  IP: 0 after deductible OP: 0 after deductible     2500/5000
# 1  IP: 0 after deductible OP: 0 after deductible     2500/5000
# 2  IP: 0 after deductible OP: 0 after deductible     2500/5001
# 3  IP: 0 after deductible OP: 0 after deductible     2500/5002
# 4  IP: 0 after deductible OP: 0 after deductible     2500/5003
# 5  IP: 0 after deductible OP: 0 after deductible     2500/5004
#
#   IN Coinsurance % IN Coinsurance Limit IN Out of Pocket Maximum  \
# 0              100            3000/6000                3000/6001
# 1               90          32000/50000              32000/50000
# 2               91          32000/50001              32000/50001
# 3               92          32000/50002              32000/50002
# 4               93          32000/50003              32000/50003
# 5               94          32000/50004              32000/50004
#
#   OON Deductible OON Coinsurance % OON Coinsurance Limit  \
# 0      2500/5002                92           32000/50002
# 1      2500/5003                93           32000/50003
# 2      2500/5004                94           32000/50004
# 3      2500/5002                92           32000/50002
# 4      2500/5003                93           32000/50003
# 5      2500/5004                94           32000/50004
#
#   OON Out of Pocket Maximum Rx Copays (OV/Spec Copay must be listed above)  \
# 0               32000/50002                                       10/25/50
# 1               32000/50003                                            NaN
# 2               32000/50004                                            NaN
# 3               32000/50002                                       10/25/50
# 4               32000/50003                                            NaN
# 5               32000/50004                                            NaN
#
#   List all three parts of the benefit: visit or dollar limit, INN cost share and OON cost share  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                              All radiology at 100%
# 4                                                NaN
# 5                                                NaN
#
#   Rx Copays (OV/Spec Copay must be listed above)  \
# 0                                       10/25/50
# 1                                            NaN
# 2                                            NaN
# 3                                       10/25/50
# 4                                            NaN
# 5                                            NaN
#
#   List all three parts of the benefit: visit or dollar limit, INN cost share and OON cost share
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                              All radiology at 100%
# 4                                                NaN
# 5                                                NaN

# %% [markdown]
# ## Concatenating All the dfs

# %%
def combine_data(clean_dfs):
    # Check for duplicate column names in each DataFrame
    for i, df in enumerate(clean_dfs):
        if df.columns.duplicated().any():
            # Drop duplicate columns
            df = df.loc[:, ~df.columns.duplicated()]
            clean_dfs[i] = df  # Update the DataFrame in the list

    # Concatenate the DataFrames
    concatenated_df = pd.concat(clean_dfs, ignore_index=True)
    return concatenated_df




# Example usage:
final_df = combine_data(clean_dfs)
final_df
# Out:
#    Group Name: Group Number(or TBD)        Request Date:  \
# 0    Tesla Inc               554658  2020-04-02 00:00:00
# 1    Tesla Inc               554658  2020-04-02 00:00:00
# 2    Tesla Inc               554658  2020-04-02 00:00:00
# 3    Tesla Inc               554658  2020-04-02 00:00:00
# 4    Tesla Inc               554658  2020-04-02 00:00:00
# ..         ...                  ...                  ...
# 63  ABCDEF Inc               554658  2020-04-02 00:00:00
# 64  ABCDEF Inc               554658  2020-04-02 00:00:00
# 65  ABCDEF Inc               554658  2020-04-02 00:00:00
# 66  ABCDEF Inc               554658  2020-04-02 00:00:00
# 67  ABCDEF Inc               554658  2020-04-02 00:00:00
#
#    Effective Date or NSB:              Benefits Status  \
# 0     2020-01-03 00:00:00  Benefits Currently in Place
# 1     2020-01-03 00:00:00  Benefits Currently in Place
# 2     2020-01-03 00:00:00  Benefits Currently in Place
# 3     2020-01-03 00:00:00           Requested Benefits
# 4     2020-01-03 00:00:00           Requested Benefits
# ..                    ...                          ...
# 63    2020-01-03 00:00:00  Benefits Currently in Place
# 64    2020-01-03 00:00:00  Benefits Currently in Place
# 65    2020-01-03 00:00:00           Requested Benefits
# 66    2020-01-03 00:00:00           Requested Benefits
# 67    2020-01-03 00:00:00           Requested Benefits
#
#                    Plan Information               CSP  \
# 0   Current Plan 1: P0145445 BUY UP  Freedom HMO 2323
# 1   Current Plan 2: P0145445 BUY UP  Freedom HMO 2324
# 2   Current Plan 3: P0145445 BUY UP  Freedom HMO 2325
# 3   Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 4   Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# ..                              ...               ...
# 63  Current Plan 2: P0145445 BUY UP  Freedom HMO 2324
# 64  Current Plan 3: P0145445 BUY UP  Freedom HMO 2325
# 65  Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 66  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 67  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
#
#    Base (Similar standard plan) Tracking ID No of Employees Enrolled:  \
# 0                                       NaN                        23
# 1                                       NaN                        25
# 2                                       NaN                        45
# 3                      KACTOHP58- MNS000025                        36
# 4                      KACTOHP58- MNS000026                        26
# ..                                      ...                       ...
# 63                                      NaN                        25
# 64                                      NaN                        45
# 65                     KACTOHP58- MNS000025                        36
# 66                     KACTOHP58- MNS000026                        26
# 67                     KACTOHP58- MNS000027                        15
#
#    Group State (NY,NJ,CT) Market (Large or Small) Product     Access  Network  \
# 0                      NJ                   Large     HMO  Non Gated  Freedom
# 1                      NJ                   Large     HMO  Non Gated  Freedom
# 2                      NJ                   Large     HMO  Non Gated  Freedom
# 3                      NJ                   Large     HMO  Non Gated  Freedom
# 4                      NJ                   Large     HMO  Non Gated  Freedom
# ..                    ...                     ...     ...        ...      ...
# 63                     NJ                   Large     HMO  Non Gated  Freedom
# 64                     NJ                   Large     HMO  Non Gated  Freedom
# 65                     NJ                   Large     HMO  Non Gated  Freedom
# 66                     NJ                   Large     HMO  Non Gated  Freedom
# 67                     NJ                   Large     HMO  Non Gated  Freedom
#
#    PCP/Specialist OV Copay ER Cost Share  \
# 0                    30/45           150
# 1                    30/50           160
# 2                      0/0           NaN
# 3                    30/55           NaN
# 4                    30/60           NaN
# ..                     ...           ...
# 63                   30/50           160
# 64                     0/0           NaN
# 65                   30/55           NaN
# 66                   30/60           NaN
# 67                     0/1           NaN
#
#                              Hospital Cost Share  IN Deductible  \
# 0   IP: 0 after deductible OP: 0 after deductible     2500/5000
# 1   IP: 0 after deductible OP: 0 after deductible     2500/5000
# 2   IP: 0 after deductible OP: 0 after deductible     2500/5001
# 3   IP: 0 after deductible OP: 0 after deductible     2500/5002
# 4   IP: 0 after deductible OP: 0 after deductible     2500/5003
# ..                                            ...           ...
# 63  IP: 0 after deductible OP: 0 after deductible     2500/5000
# 64  IP: 0 after deductible OP: 0 after deductible     2500/5001
# 65  IP: 0 after deductible OP: 0 after deductible     2500/5002
# 66  IP: 0 after deductible OP: 0 after deductible     2500/5003
# 67  IP: 0 after deductible OP: 0 after deductible     2500/5004
#
#    IN Coinsurance % IN Coinsurance Limit IN Out of Pocket Maximum  \
# 0               100            3000/6000                3000/6001
# 1                90          32000/50000              32000/50000
# 2                91          32000/50001              32000/50001
# 3                92          32000/50002              32000/50002
# 4                93          32000/50003              32000/50003
# ..              ...                  ...                      ...
# 63               90          32000/50000              32000/50000
# 64               91          32000/50001              32000/50001
# 65               92          32000/50002              32000/50002
# 66               93          32000/50003              32000/50003
# 67               94          32000/50004              32000/50004
#
#    OON Deductible OON Coinsurance % OON Coinsurance Limit  \
# 0       2500/5002                92           32000/50002
# 1       2500/5003                93           32000/50003
# 2       2500/5004                94           32000/50004
# 3       2500/5002                92           32000/50002
# 4       2500/5003                93           32000/50003
# ..            ...               ...                   ...
# 63      2500/5003                93           32000/50003
# 64      2500/5004                94           32000/50004
# 65      2500/5002                92           32000/50002
# 66      2500/5003                93           32000/50003
# 67      2500/5004                94           32000/50004
#
#    OON Out of Pocket Maximum Rx Copays (OV/Spec Copay must be listed above)  \
# 0                32000/50002                                       10/25/50
# 1                32000/50003                                            NaN
# 2                32000/50004                                            NaN
# 3                32000/50002                                       10/25/50
# 4                32000/50003                                            NaN
# ..                       ...                                            ...
# 63               32000/50003                                            NaN
# 64               32000/50004                                            NaN
# 65               32000/50002                                       10/25/50
# 66               32000/50003                                            NaN
# 67               32000/50004                                            NaN
#
#    List all three parts of the benefit: visit or dollar limit, INN cost share and OON cost share
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                               All radiology at 100%
# 4                                                 NaN
# ..                                                ...
# 63                                                NaN
# 64                                                NaN
# 65                              All radiology at 100%
# 66                                                NaN
# 67                                                NaN
#
# [68 rows x 27 columns]

# %%
import numpy as np
import pandas as pd

def filter_requested_benefits(final_df):
    final_df = final_df[final_df.apply(lambda row: 'Requested Benefits' in row.values, axis=1)]
    return final_df

def split_special_columns(final_df):
    column_to_split = 'PCP/Specialist OV Copay'
    if column_to_split in final_df.columns:
        split_cols = final_df[column_to_split].str.split('/', expand=True)
        final_df['PCP OV Copay'] = split_cols[0].astype(str).str.strip()
        final_df['Specialist OV Copay'] = split_cols[1].astype(str).str.strip()
        final_df.drop(columns=[column_to_split], inplace=True)
    return final_df
    

def split_columns(final_df):
    for col in final_df.columns:
        if final_df[col].apply(lambda x: '/' in str(x)).any():
            split_cols = final_df[col].str.split('/', expand=True)
            final_df[f'IND {col}'] = split_cols[0].astype(str).str.strip()
            final_df[f'FAMILY {col}'] = split_cols[1].astype(str).str.strip()
            final_df.drop(columns=[col], inplace=True)
    return final_df

def rename_columns(final_df):
    final_df = final_df.rename(columns={
        'Group Name:': 'Group Name',
        'FAMILY OON Deductible': 'FAMILY DEDUCTIBLE OON',
        'IND OON Deductible': 'IND DEDUCTIBLE OON',
        'FAMILY IN Deductible': 'FAMILY DEDUCTIBLE INN',
        'IND IN Deductible': 'IND DEDUCTIBLE INN',
        'FAMILY OON Out of Pocket Maximum': 'FAMILY OOP OON',
        'FAMILY IN Out of Pocket Maximum': 'FAMILY OOP INN',
        'IND IN Out of Pocket Maximum': 'IND OOP INN',
        'IND OON Out of Pocket Maximum': 'IND OOP OON',
        'Product': 'Product Name',
        'PCP OV Copay': 'PCP COPAY',
        'ER Cost Share': 'EMERGENCY ROOM COPAY',
        'Specialist OV Copay': 'SPEC COPAY',
        'Network': 'Network Description',
        'IN Coinsurance %': 'INN COINSURANCE',
        'OON Coinsurance %': 'OON COINSURANCE'
    })
    return final_df

# Assuming final_df is already populated
final_df = filter_requested_benefits(final_df)
final_df = split_special_columns(final_df)
final_df = split_columns(final_df)
final_df = rename_columns(final_df)

final_df
# Out:
# C:\Users\shres\AppData\Local\Temp\ipykernel_36028\3027659184.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['PCP OV Copay'] = split_cols[0].astype(str).str.strip()
# C:\Users\shres\AppData\Local\Temp\ipykernel_36028\3027659184.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['Specialist OV Copay'] = split_cols[1].astype(str).str.strip()
# C:\Users\shres\AppData\Local\Temp\ipykernel_36028\3027659184.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=[column_to_split], inplace=True)
# C:\Users\shres\AppData\Local\Temp\ipykernel_36028\3027659184.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df[f'IND {col}'] = split_cols[0].astype(str).str.strip()
# C:\Users\shres\AppData\Local\Temp\ipykernel_36028\3027659184.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df[f'FAMILY {col}'] = split_cols[1].astype(str).str.strip()
# C:\Users\shres\AppData\Local\Temp\ipykernel_36028\3027659184.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=[col], inplace=True)
# C:\Users\shres\AppData\Local\Temp\ipykernel_36028\3027659184.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df[f'IND {col}'] = split_cols[0].astype(str).str.strip()
# C:\Users\shres\AppData\Local\Temp\ipykernel_36028\3027659184.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df[f'FAMILY {col}'] = split_cols[1].astype(str).str.strip()
# C:\Users\shres\AppData\Local\Temp\ipykernel_36028\3027659184.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=[col], inplace=True)
# C:\Users\shres\AppData\Local\Temp\ipykernel_36028\3027659184.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df[f'IND {col}'] = split_cols[0].astype(str).str.strip()
# C:\Users\shres\AppData\Local\Temp\ipykernel_36028\3027659184.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df[f'FAMILY {col}'] = split_cols[1].astype(str).str.strip()
# C:\Users\shres\AppData\Local\Temp\ipykernel_36028\3027659184.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=[col], inplace=True)
# C:\Users\shres\AppData\Local\Temp\ipykernel_36028\3027659184.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df[f'IND {col}'] = split_cols[0].astype(str).str.strip()
# C:\Users\shres\AppData\Local\Temp\ipykernel_36028\3027659184.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df[f'FAMILY {col}'] = split_cols[1].astype(str).str.strip()
# C:\Users\shres\AppData\Local\Temp\ipykernel_36028\3027659184.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=[col], inplace=True)
# C:\Users\shres\AppData\Local\Temp\ipykernel_36028\3027659184.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df[f'IND {col}'] = split_cols[0].astype(str).str.strip()
# C:\Users\shres\AppData\Local\Temp\ipykernel_36028\3027659184.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df[f'FAMILY {col}'] = split_cols[1].astype(str).str.strip()
# C:\Users\shres\AppData\Local\Temp\ipykernel_36028\3027659184.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=[col], inplace=True)
# C:\Users\shres\AppData\Local\Temp\ipykernel_36028\3027659184.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df[f'IND {col}'] = split_cols[0].astype(str).str.strip()
# C:\Users\shres\AppData\Local\Temp\ipykernel_36028\3027659184.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df[f'FAMILY {col}'] = split_cols[1].astype(str).str.strip()
# C:\Users\shres\AppData\Local\Temp\ipykernel_36028\3027659184.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=[col], inplace=True)
# C:\Users\shres\AppData\Local\Temp\ipykernel_36028\3027659184.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df[f'IND {col}'] = split_cols[0].astype(str).str.strip()
# C:\Users\shres\AppData\Local\Temp\ipykernel_36028\3027659184.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df[f'FAMILY {col}'] = split_cols[1].astype(str).str.strip()
# C:\Users\shres\AppData\Local\Temp\ipykernel_36028\3027659184.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=[col], inplace=True)
#     Group Name Group Number(or TBD)        Request Date:  \
# 3    Tesla Inc               554658  2020-04-02 00:00:00
# 4    Tesla Inc               554658  2020-04-02 00:00:00
# 5    Tesla Inc               554658  2020-04-02 00:00:00
# 9    Tesla Inc               554658  2021-04-02 00:00:00
# 10   Tesla Inc               554658  2021-04-02 00:00:00
# 11   Tesla Inc               554658  2021-04-02 00:00:00
# 15   Tesla Inc               554658  2022-04-02 00:00:00
# 16   Tesla Inc               554658  2022-04-02 00:00:00
# 17   Tesla Inc               554658  2022-04-02 00:00:00
# 21   Tesla Inc               554658  2023-04-02 00:00:00
# 22   Tesla Inc               554658  2023-04-02 00:00:00
# 23   Tesla Inc               554658  2023-04-02 00:00:00
# 27   Tesla Inc               554658  2024-04-02 00:00:00
# 28   Tesla Inc               554658  2024-04-02 00:00:00
# 29   Tesla Inc               554658  2024-04-02 00:00:00
# 33  Tienam Inc               554556  2020-04-02 00:00:00
# 34  Tienam Inc               554556  2020-04-02 00:00:00
# 35  Tienam Inc               554556  2020-04-02 00:00:00
# 36  Tienam Inc               554556  2020-04-02 00:00:00
# 37  Tienam Inc               554556  2020-04-02 00:00:00
# 41  Tienam Inc               554556  2022-04-02 00:00:00
# 42  Tienam Inc               554556  2022-04-02 00:00:00
# 43  Tienam Inc               554556  2022-04-02 00:00:00
# 47   Apple Inc               554658  2020-04-02 00:00:00
# 48   Apple Inc               554658  2020-04-02 00:00:00
# 49   Apple Inc               554658  2020-04-02 00:00:00
# 53     XYZ Inc               554556  2020-04-02 00:00:00
# 54     XYZ Inc               554556  2020-04-02 00:00:00
# 55     XYZ Inc               554556  2020-04-02 00:00:00
# 59     XYZ Inc               554556  2020-04-02 00:00:00
# 60     XYZ Inc               554556  2020-04-02 00:00:00
# 61     XYZ Inc               554556  2020-04-02 00:00:00
# 65  ABCDEF Inc               554658  2020-04-02 00:00:00
# 66  ABCDEF Inc               554658  2020-04-02 00:00:00
# 67  ABCDEF Inc               554658  2020-04-02 00:00:00
#
#    Effective Date or NSB:     Benefits Status  \
# 3     2020-01-03 00:00:00  Requested Benefits
# 4     2020-01-03 00:00:00  Requested Benefits
# 5     2020-01-03 00:00:00  Requested Benefits
# 9     2021-01-03 00:00:00  Requested Benefits
# 10    2021-01-03 00:00:00  Requested Benefits
# 11    2021-01-03 00:00:00  Requested Benefits
# 15    2022-01-03 00:00:00  Requested Benefits
# 16    2022-01-03 00:00:00  Requested Benefits
# 17    2022-01-03 00:00:00  Requested Benefits
# 21    2023-01-03 00:00:00  Requested Benefits
# 22    2023-01-03 00:00:00  Requested Benefits
# 23    2023-01-03 00:00:00  Requested Benefits
# 27    2024-01-03 00:00:00  Requested Benefits
# 28    2024-01-03 00:00:00  Requested Benefits
# 29    2024-01-03 00:00:00  Requested Benefits
# 33    2020-01-03 00:00:00  Requested Benefits
# 34    2020-01-03 00:00:00  Requested Benefits
# 35    2020-01-03 00:00:00  Requested Benefits
# 36    2020-01-03 00:00:00  Requested Benefits
# 37    2020-01-03 00:00:00  Requested Benefits
# 41    2022-01-03 00:00:00  Requested Benefits
# 42    2022-01-03 00:00:00  Requested Benefits
# 43    2022-01-03 00:00:00  Requested Benefits
# 47    2020-01-03 00:00:00  Requested Benefits
# 48    2020-01-03 00:00:00  Requested Benefits
# 49    2020-01-03 00:00:00  Requested Benefits
# 53    2020-01-03 00:00:00  Requested Benefits
# 54    2020-01-03 00:00:00  Requested Benefits
# 55    2020-01-03 00:00:00  Requested Benefits
# 59    2020-01-03 00:00:00  Requested Benefits
# 60    2020-01-03 00:00:00  Requested Benefits
# 61    2020-01-03 00:00:00  Requested Benefits
# 65    2020-01-03 00:00:00  Requested Benefits
# 66    2020-01-03 00:00:00  Requested Benefits
# 67    2020-01-03 00:00:00  Requested Benefits
#
#                    Plan Information               CSP  \
# 3   Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 4   Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 5   Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
# 9   Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 10  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 11  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
# 15  Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 16  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 17  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
# 21  Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 22  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 23  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
# 27  Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 28  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 29  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
# 33  Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 34  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 35  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
# 36                              NaN               NaN
# 37                              NaN               NaN
# 41  Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 42  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 43  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
# 47  Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 48  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 49  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
# 53  Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 54  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 55  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
# 59  Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 60  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 61  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
# 65  Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 66  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 67  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
#
#    Base (Similar standard plan) Tracking ID No of Employees Enrolled:  \
# 3                      KACTOHP58- MNS000025                        36
# 4                      KACTOHP58- MNS000026                        26
# 5                      KACTOHP58- MNS000027                        15
# 9                      KACTOHP58- MNS000025                        36
# 10                     KACTOHP58- MNS000026                        26
# 11                     KACTOHP58- MNS000027                        15
# 15                     KACTOHP58- MNS000025                        36
# 16                     KACTOHP58- MNS000026                        26
# 17                     KACTOHP58- MNS000027                        15
# 21                     KACTOHP58- MNS000025                        36
# 22                     KACTOHP58- MNS000026                        26
# 23                     KACTOHP58- MNS000027                        15
# 27                     KACTOHP58- MNS000025                        36
# 28                     KACTOHP58- MNS000026                        26
# 29                     KACTOHP58- MNS000027                        15
# 33                     KACTOHP58- MNS000025                        36
# 34                     KACTOHP58- MNS000026                        26
# 35                     KACTOHP58- MNS000027                        15
# 36                                      NaN                       NaN
# 37                                      NaN                       NaN
# 41                     KACTOHP58- MNS000025                        36
# 42                     KACTOHP58- MNS000026                        26
# 43                     KACTOHP58- MNS000027                        15
# 47                     KACTOHP58- MNS000025                        36
# 48                     KACTOHP58- MNS000026                        26
# 49                     KACTOHP58- MNS000027                        15
# 53                     KACTOHP58- MNS000025                        36
# 54                     KACTOHP58- MNS000026                        26
# 55                     KACTOHP58- MNS000027                        15
# 59                     KACTOHP58- MNS000025                        36
# 60                     KACTOHP58- MNS000026                        26
# 61                     KACTOHP58- MNS000027                        15
# 65                     KACTOHP58- MNS000025                        36
# 66                     KACTOHP58- MNS000026                        26
# 67                     KACTOHP58- MNS000027                        15
#
#    Group State (NY,NJ,CT) Market (Large or Small) Product Name     Access  \
# 3                      NJ                   Large          HMO  Non Gated
# 4                      NJ                   Large          HMO  Non Gated
# 5                      NJ                   Large          HMO  Non Gated
# 9                      NJ                   Large          HMO  Non Gated
# 10                     NJ                   Large          HMO  Non Gated
# 11                     NJ                   Large          HMO  Non Gated
# 15                     NJ                   Large          HMO  Non Gated
# 16                     NJ                   Large          HMO  Non Gated
# 17                     NJ                   Large          HMO  Non Gated
# 21                     NJ                   Large          HMO  Non Gated
# 22                     NJ                   Large          HMO  Non Gated
# 23                     NJ                   Large          HMO  Non Gated
# 27                     NJ                   Large          HMO  Non Gated
# 28                     NJ                   Large          HMO  Non Gated
# 29                     NJ                   Large          HMO  Non Gated
# 33                     NJ                   Large          HMO  Non Gated
# 34                     NJ                   Large          HMO  Non Gated
# 35                     NJ                   Large          HMO  Non Gated
# 36                    NaN                     NaN          NaN        NaN
# 37                    NaN                     NaN          NaN        NaN
# 41                     NJ                   Large          HMO  Non Gated
# 42                     NJ                   Large          HMO  Non Gated
# 43                     NJ                   Large          HMO  Non Gated
# 47                     NJ                   Large          HMO  Non Gated
# 48                     NJ                   Large          HMO  Non Gated
# 49                     NJ                   Large          HMO  Non Gated
# 53                     NJ                   Large          HMO  Non Gated
# 54                     NJ                   Large          HMO  Non Gated
# 55                     NJ                   Large          HMO  Non Gated
# 59                     NJ                   Large          HMO  Non Gated
# 60                     NJ                   Large          HMO  Non Gated
# 61                     NJ                   Large          HMO  Non Gated
# 65                     NJ                   Large          HMO  Non Gated
# 66                     NJ                   Large          HMO  Non Gated
# 67                     NJ                   Large          HMO  Non Gated
#
#    Network Description EMERGENCY ROOM COPAY  \
# 3              Freedom                  NaN
# 4              Freedom                  NaN
# 5              Freedom                  NaN
# 9              Freedom                  NaN
# 10             Freedom                  NaN
# 11             Freedom                  NaN
# 15             Freedom                  NaN
# 16             Freedom                  NaN
# 17             Freedom                  NaN
# 21             Freedom                  NaN
# 22             Freedom                  NaN
# 23             Freedom                  NaN
# 27             Freedom                  NaN
# 28             Freedom                  NaN
# 29             Freedom                  NaN
# 33             Freedom                  NaN
# 34             Freedom                  NaN
# 35             Freedom                  NaN
# 36                 NaN                  NaN
# 37                 NaN                  NaN
# 41             Freedom                  NaN
# 42             Freedom                  NaN
# 43             Freedom                  NaN
# 47             Freedom                  NaN
# 48             Freedom                  NaN
# 49             Freedom                  NaN
# 53             Freedom                  NaN
# 54             Freedom                  NaN
# 55             Freedom                  NaN
# 59             Freedom                  NaN
# 60             Freedom                  NaN
# 61             Freedom                  NaN
# 65             Freedom                  NaN
# 66             Freedom                  NaN
# 67             Freedom                  NaN
#
#                              Hospital Cost Share  INN COINSURANCE  \
# 3   IP: 0 after deductible OP: 0 after deductible              92
# 4   IP: 0 after deductible OP: 0 after deductible              93
# 5   IP: 0 after deductible OP: 0 after deductible              94
# 9   IP: 0 after deductible OP: 0 after deductible              92
# 10  IP: 0 after deductible OP: 0 after deductible              93
# 11  IP: 0 after deductible OP: 0 after deductible              94
# 15  IP: 0 after deductible OP: 0 after deductible              92
# 16  IP: 0 after deductible OP: 0 after deductible              93
# 17  IP: 0 after deductible OP: 0 after deductible              94
# 21  IP: 0 after deductible OP: 0 after deductible              92
# 22  IP: 0 after deductible OP: 0 after deductible              93
# 23  IP: 0 after deductible OP: 0 after deductible              94
# 27  IP: 0 after deductible OP: 0 after deductible              92
# 28  IP: 0 after deductible OP: 0 after deductible              93
# 29  IP: 0 after deductible OP: 0 after deductible              94
# 33  IP: 0 after deductible OP: 0 after deductible              92
# 34  IP: 0 after deductible OP: 0 after deductible              93
# 35  IP: 0 after deductible OP: 0 after deductible              94
# 36                                            NaN             NaN
# 37                                            NaN             NaN
# 41  IP: 0 after deductible OP: 0 after deductible              92
# 42  IP: 0 after deductible OP: 0 after deductible              93
# 43  IP: 0 after deductible OP: 0 after deductible              94
# 47  IP: 0 after deductible OP: 0 after deductible              92
# 48  IP: 0 after deductible OP: 0 after deductible              93
# 49  IP: 0 after deductible OP: 0 after deductible              94
# 53  IP: 0 after deductible OP: 0 after deductible              92
# 54  IP: 0 after deductible OP: 0 after deductible              93
# 55  IP: 0 after deductible OP: 0 after deductible              94
# 59  IP: 0 after deductible OP: 0 after deductible              92
# 60  IP: 0 after deductible OP: 0 after deductible              93
# 61  IP: 0 after deductible OP: 0 after deductible              94
# 65  IP: 0 after deductible OP: 0 after deductible              92
# 66  IP: 0 after deductible OP: 0 after deductible              93
# 67  IP: 0 after deductible OP: 0 after deductible              94
#
#    OON COINSURANCE  \
# 3               92
# 4               93
# 5               94
# 9               92
# 10              93
# 11              94
# 15              92
# 16              93
# 17              94
# 21              92
# 22              93
# 23              94
# 27              92
# 28              93
# 29              94
# 33              92
# 34              93
# 35              94
# 36             NaN
# 37             NaN
# 41              92
# 42              93
# 43              94
# 47              92
# 48              93
# 49              94
# 53              92
# 54              93
# 55              94
# 59              92
# 60              93
# 61              94
# 65              92
# 66              93
# 67              94
#
#    List all three parts of the benefit: visit or dollar limit, INN cost share and OON cost share  \
# 3                               All radiology at 100%
# 4                                                 NaN
# 5                                                 NaN
# 9                               All radiology at 100%
# 10                                                NaN
# 11                                                NaN
# 15                              All radiology at 100%
# 16                                                NaN
# 17                                                NaN
# 21                              All radiology at 100%
# 22                                                NaN
# 23                                                NaN
# 27                              All radiology at 100%
# 28                                                NaN
# 29                                                NaN
# 33                              All radiology at 100%
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 41                              All radiology at 100%
# 42                                                NaN
# 43                                                NaN
# 47                              All radiology at 100%
# 48                                                NaN
# 49                                                NaN
# 53                              All radiology at 100%
# 54                                                NaN
# 55                                                NaN
# 59                              All radiology at 100%
# 60                                                NaN
# 61                                                NaN
# 65                              All radiology at 100%
# 66                                                NaN
# 67                                                NaN
#
#    PCP COPAY SPEC COPAY IND DEDUCTIBLE INN FAMILY DEDUCTIBLE INN  \
# 3         30         55               2500                  5002
# 4         30         60               2500                  5003
# 5          0          1               2500                  5004
# 9         30         55               2500                  5002
# 10        30         60               2500                  5003
# 11         0          1               2500                  5004
# 15        30         55               2500                  5002
# 16        30         60               2500                  5003
# 17         0          1               2500                  5004
# 21        30         55               2500                  5002
# 22        30         60               2500                  5003
# 23         0          1               2500                  5004
# 27        30         55               2500                  5002
# 28        30         60               2500                  5003
# 29         0          1               2500                  5004
# 33        30         55               2500                  5002
# 34        30         60               2500                  5003
# 35         0          1               2500                  5004
# 36       nan        nan                nan                   nan
# 37       nan        nan                nan                   nan
# 41        30         55               2500                  5002
# 42        30         60               2500                  5003
# 43         0          1               2500                  5004
# 47        30         55               2500                  5002
# 48        30         60               2500                  5003
# 49         0          1               2500                  5004
# 53        30         55               2500                  5002
# 54        30         60               2500                  5003
# 55         0          1               2500                  5004
# 59        30         55               2500                  5002
# 60        30         60               2500                  5003
# 61         0          1               2500                  5004
# 65        30         55               2500                  5002
# 66        30         60               2500                  5003
# 67         0          1               2500                  5004
#
#    IND IN Coinsurance Limit FAMILY IN Coinsurance Limit IND OOP INN  \
# 3                     32000                       50002       32000
# 4                     32000                       50003       32000
# 5                     32000                       50004       32000
# 9                     32000                       50002       32000
# 10                    32000                       50003       32000
# 11                    32000                       50004       32000
# 15                    32000                       50002       32000
# 16                    32000                       50003       32000
# 17                    32000                       50004       32000
# 21                    32000                       50002       32000
# 22                    32000                       50003       32000
# 23                    32000                       50004       32000
# 27                    32000                       50002       32000
# 28                    32000                       50003       32000
# 29                    32000                       50004       32000
# 33                    32000                       50002       32000
# 34                    32000                       50003       32000
# 35                    32000                       50004       32000
# 36                      nan                         nan         nan
# 37                      nan                         nan         nan
# 41                    32000                       50002       32000
# 42                    32000                       50003       32000
# 43                    32000                       50004       32000
# 47                    32000                       50002       32000
# 48                    32000                       50003       32000
# 49                    32000                       50004       32000
# 53                    32000                       50002       32000
# 54                    32000                       50003       32000
# 55                    32000                       50004       32000
# 59                    32000                       50002       32000
# 60                    32000                       50003       32000
# 61                    32000                       50004       32000
# 65                    32000                       50002       32000
# 66                    32000                       50003       32000
# 67                    32000                       50004       32000
#
#    FAMILY OOP INN IND DEDUCTIBLE OON FAMILY DEDUCTIBLE OON  \
# 3           50002               2500                  5002
# 4           50003               2500                  5003
# 5           50004               2500                  5004
# 9           50002               2500                  5002
# 10          50003               2500                  5003
# 11          50004               2500                  5004
# 15          50002               2500                  5002
# 16          50003               2500                  5003
# 17          50004               2500                  5004
# 21          50002               2500                  5002
# 22          50003               2500                  5003
# 23          50004               2500                  5004
# 27          50002               2500                  5002
# 28          50003               2500                  5003
# 29          50004               2500                  5004
# 33          50002               2500                  5002
# 34          50003               2500                  5003
# 35          50004               2500                  5004
# 36            nan                nan                   nan
# 37            nan                nan                   nan
# 41          50002               2500                  5002
# 42          50003               2500                  5003
# 43          50004               2500                  5004
# 47          50002               2500                  5002
# 48          50003               2500                  5003
# 49          50004               2500                  5004
# 53          50002               2500                  5002
# 54          50003               2500                  5003
# 55          50004               2500                  5004
# 59          50002               2500                  5002
# 60          50003               2500                  5003
# 61          50004               2500                  5004
# 65          50002               2500                  5002
# 66          50003               2500                  5003
# 67          50004               2500                  5004
#
#    IND OON Coinsurance Limit FAMILY OON Coinsurance Limit IND OOP OON  \
# 3                      32000                        50002       32000
# 4                      32000                        50003       32000
# 5                      32000                        50004       32000
# 9                      32000                        50002       32000
# 10                     32000                        50003       32000
# 11                     32000                        50004       32000
# 15                     32000                        50002       32000
# 16                     32000                        50003       32000
# 17                     32000                        50004       32000
# 21                     32000                        50002       32000
# 22                     32000                        50003       32000
# 23                     32000                        50004       32000
# 27                     32000                        50002       32000
# 28                     32000                        50003       32000
# 29                     32000                        50004       32000
# 33                     32000                        50002       32000
# 34                     32000                        50003       32000
# 35                     32000                        50004       32000
# 36                       nan                          nan         nan
# 37                       nan                          nan         nan
# 41                     32000                        50002       32000
# 42                     32000                        50003       32000
# 43                     32000                        50004       32000
# 47                     32000                        50002       32000
# 48                     32000                        50003       32000
# 49                     32000                        50004       32000
# 53                     32000                        50002       32000
# 54                     32000                        50003       32000
# 55                     32000                        50004       32000
# 59                     32000                        50002       32000
# 60                     32000                        50003       32000
# 61                     32000                        50004       32000
# 65                     32000                        50002       32000
# 66                     32000                        50003       32000
# 67                     32000                        50004       32000
#
#    FAMILY OOP OON IND Rx Copays (OV/Spec Copay must be listed above)  \
# 3           50002                                                 10
# 4           50003                                                nan
# 5           50004                                                nan
# 9           50002                                                 10
# 10          50003                                                nan
# 11          50004                                                nan
# 15          50002                                                 10
# 16          50003                                                nan
# 17          50004                                                nan
# 21          50002                                                 10
# 22          50003                                                nan
# 23          50004                                                nan
# 27          50002                                                 10
# 28          50003                                                nan
# 29          50004                                                nan
# 33          50002                                                 10
# 34          50003                                                nan
# 35          50004                                                nan
# 36            nan                                                nan
# 37            nan                                                nan
# 41          50002                                                 10
# 42          50003                                                nan
# 43          50004                                                nan
# 47          50002                                                 10
# 48          50003                                                nan
# 49          50004                                                nan
# 53          50002                                                 10
# 54          50003                                                nan
# 55          50004                                                nan
# 59          50002                                                 10
# 60          50003                                                nan
# 61          50004                                                nan
# 65          50002                                                 10
# 66          50003                                                nan
# 67          50004                                                nan
#
#    FAMILY Rx Copays (OV/Spec Copay must be listed above)
# 3                                                  25
# 4                                                 nan
# 5                                                 nan
# 9                                                  25
# 10                                                nan
# 11                                                nan
# 15                                                 25
# 16                                                nan
# 17                                                nan
# 21                                                 25
# 22                                                nan
# 23                                                nan
# 27                                                 25
# 28                                                nan
# 29                                                nan
# 33                                                 25
# 34                                                nan
# 35                                                nan
# 36                                                nan
# 37                                                nan
# 41                                                 25
# 42                                                nan
# 43                                                nan
# 47                                                 25
# 48                                                nan
# 49                                                nan
# 53                                                 25
# 54                                                nan
# 55                                                nan
# 59                                                 25
# 60                                                nan
# 61                                                nan
# 65                                                 25
# 66                                                nan
# 67                                                nan

# %%
# Assuming final_df is already populated
final_df = filter_requested_benefits(final_df)
final_df = split_special_columns(final_df)
final_df = split_columns(final_df)
final_df = rename_columns(final_df)

# %%
final_df
# Out:
#     Group Name Group Number(or TBD)        Request Date:  \
# 3    Tesla Inc               554658  2020-04-02 00:00:00
# 4    Tesla Inc               554658  2020-04-02 00:00:00
# 5    Tesla Inc               554658  2020-04-02 00:00:00
# 9    Tesla Inc               554658  2021-04-02 00:00:00
# 10   Tesla Inc               554658  2021-04-02 00:00:00
# 11   Tesla Inc               554658  2021-04-02 00:00:00
# 15   Tesla Inc               554658  2022-04-02 00:00:00
# 16   Tesla Inc               554658  2022-04-02 00:00:00
# 17   Tesla Inc               554658  2022-04-02 00:00:00
# 21   Tesla Inc               554658  2023-04-02 00:00:00
# 22   Tesla Inc               554658  2023-04-02 00:00:00
# 23   Tesla Inc               554658  2023-04-02 00:00:00
# 27   Tesla Inc               554658  2024-04-02 00:00:00
# 28   Tesla Inc               554658  2024-04-02 00:00:00
# 29   Tesla Inc               554658  2024-04-02 00:00:00
# 33  Tienam Inc               554556  2020-04-02 00:00:00
# 34  Tienam Inc               554556  2020-04-02 00:00:00
# 35  Tienam Inc               554556  2020-04-02 00:00:00
# 36  Tienam Inc               554556  2020-04-02 00:00:00
# 37  Tienam Inc               554556  2020-04-02 00:00:00
# 41  Tienam Inc               554556  2022-04-02 00:00:00
# 42  Tienam Inc               554556  2022-04-02 00:00:00
# 43  Tienam Inc               554556  2022-04-02 00:00:00
# 47   Apple Inc               554658  2020-04-02 00:00:00
# 48   Apple Inc               554658  2020-04-02 00:00:00
# 49   Apple Inc               554658  2020-04-02 00:00:00
# 53     XYZ Inc               554556  2020-04-02 00:00:00
# 54     XYZ Inc               554556  2020-04-02 00:00:00
# 55     XYZ Inc               554556  2020-04-02 00:00:00
# 59     XYZ Inc               554556  2020-04-02 00:00:00
# 60     XYZ Inc               554556  2020-04-02 00:00:00
# 61     XYZ Inc               554556  2020-04-02 00:00:00
# 65  ABCDEF Inc               554658  2020-04-02 00:00:00
# 66  ABCDEF Inc               554658  2020-04-02 00:00:00
# 67  ABCDEF Inc               554658  2020-04-02 00:00:00
#
#    Effective Date or NSB:     Benefits Status  \
# 3     2020-01-03 00:00:00  Requested Benefits
# 4     2020-01-03 00:00:00  Requested Benefits
# 5     2020-01-03 00:00:00  Requested Benefits
# 9     2021-01-03 00:00:00  Requested Benefits
# 10    2021-01-03 00:00:00  Requested Benefits
# 11    2021-01-03 00:00:00  Requested Benefits
# 15    2022-01-03 00:00:00  Requested Benefits
# 16    2022-01-03 00:00:00  Requested Benefits
# 17    2022-01-03 00:00:00  Requested Benefits
# 21    2023-01-03 00:00:00  Requested Benefits
# 22    2023-01-03 00:00:00  Requested Benefits
# 23    2023-01-03 00:00:00  Requested Benefits
# 27    2024-01-03 00:00:00  Requested Benefits
# 28    2024-01-03 00:00:00  Requested Benefits
# 29    2024-01-03 00:00:00  Requested Benefits
# 33    2020-01-03 00:00:00  Requested Benefits
# 34    2020-01-03 00:00:00  Requested Benefits
# 35    2020-01-03 00:00:00  Requested Benefits
# 36    2020-01-03 00:00:00  Requested Benefits
# 37    2020-01-03 00:00:00  Requested Benefits
# 41    2022-01-03 00:00:00  Requested Benefits
# 42    2022-01-03 00:00:00  Requested Benefits
# 43    2022-01-03 00:00:00  Requested Benefits
# 47    2020-01-03 00:00:00  Requested Benefits
# 48    2020-01-03 00:00:00  Requested Benefits
# 49    2020-01-03 00:00:00  Requested Benefits
# 53    2020-01-03 00:00:00  Requested Benefits
# 54    2020-01-03 00:00:00  Requested Benefits
# 55    2020-01-03 00:00:00  Requested Benefits
# 59    2020-01-03 00:00:00  Requested Benefits
# 60    2020-01-03 00:00:00  Requested Benefits
# 61    2020-01-03 00:00:00  Requested Benefits
# 65    2020-01-03 00:00:00  Requested Benefits
# 66    2020-01-03 00:00:00  Requested Benefits
# 67    2020-01-03 00:00:00  Requested Benefits
#
#                    Plan Information               CSP  \
# 3   Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 4   Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 5   Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
# 9   Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 10  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 11  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
# 15  Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 16  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 17  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
# 21  Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 22  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 23  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
# 27  Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 28  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 29  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
# 33  Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 34  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 35  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
# 36                              NaN               NaN
# 37                              NaN               NaN
# 41  Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 42  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 43  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
# 47  Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 48  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 49  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
# 53  Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 54  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 55  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
# 59  Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 60  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 61  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
# 65  Current Plan 1: P0145445 BUY UP  Freedom HMO 2326
# 66  Current Plan 2: P0145445 BUY UP  Freedom HMO 2327
# 67  Current Plan 3: P0145445 BUY UP  Freedom HMO 2328
#
#    Base (Similar standard plan) Tracking ID No of Employees Enrolled:  \
# 3                      KACTOHP58- MNS000025                        36
# 4                      KACTOHP58- MNS000026                        26
# 5                      KACTOHP58- MNS000027                        15
# 9                      KACTOHP58- MNS000025                        36
# 10                     KACTOHP58- MNS000026                        26
# 11                     KACTOHP58- MNS000027                        15
# 15                     KACTOHP58- MNS000025                        36
# 16                     KACTOHP58- MNS000026                        26
# 17                     KACTOHP58- MNS000027                        15
# 21                     KACTOHP58- MNS000025                        36
# 22                     KACTOHP58- MNS000026                        26
# 23                     KACTOHP58- MNS000027                        15
# 27                     KACTOHP58- MNS000025                        36
# 28                     KACTOHP58- MNS000026                        26
# 29                     KACTOHP58- MNS000027                        15
# 33                     KACTOHP58- MNS000025                        36
# 34                     KACTOHP58- MNS000026                        26
# 35                     KACTOHP58- MNS000027                        15
# 36                                      NaN                       NaN
# 37                                      NaN                       NaN
# 41                     KACTOHP58- MNS000025                        36
# 42                     KACTOHP58- MNS000026                        26
# 43                     KACTOHP58- MNS000027                        15
# 47                     KACTOHP58- MNS000025                        36
# 48                     KACTOHP58- MNS000026                        26
# 49                     KACTOHP58- MNS000027                        15
# 53                     KACTOHP58- MNS000025                        36
# 54                     KACTOHP58- MNS000026                        26
# 55                     KACTOHP58- MNS000027                        15
# 59                     KACTOHP58- MNS000025                        36
# 60                     KACTOHP58- MNS000026                        26
# 61                     KACTOHP58- MNS000027                        15
# 65                     KACTOHP58- MNS000025                        36
# 66                     KACTOHP58- MNS000026                        26
# 67                     KACTOHP58- MNS000027                        15
#
#    Group State (NY,NJ,CT) Market (Large or Small) Product Name     Access  \
# 3                      NJ                   Large          HMO  Non Gated
# 4                      NJ                   Large          HMO  Non Gated
# 5                      NJ                   Large          HMO  Non Gated
# 9                      NJ                   Large          HMO  Non Gated
# 10                     NJ                   Large          HMO  Non Gated
# 11                     NJ                   Large          HMO  Non Gated
# 15                     NJ                   Large          HMO  Non Gated
# 16                     NJ                   Large          HMO  Non Gated
# 17                     NJ                   Large          HMO  Non Gated
# 21                     NJ                   Large          HMO  Non Gated
# 22                     NJ                   Large          HMO  Non Gated
# 23                     NJ                   Large          HMO  Non Gated
# 27                     NJ                   Large          HMO  Non Gated
# 28                     NJ                   Large          HMO  Non Gated
# 29                     NJ                   Large          HMO  Non Gated
# 33                     NJ                   Large          HMO  Non Gated
# 34                     NJ                   Large          HMO  Non Gated
# 35                     NJ                   Large          HMO  Non Gated
# 36                    NaN                     NaN          NaN        NaN
# 37                    NaN                     NaN          NaN        NaN
# 41                     NJ                   Large          HMO  Non Gated
# 42                     NJ                   Large          HMO  Non Gated
# 43                     NJ                   Large          HMO  Non Gated
# 47                     NJ                   Large          HMO  Non Gated
# 48                     NJ                   Large          HMO  Non Gated
# 49                     NJ                   Large          HMO  Non Gated
# 53                     NJ                   Large          HMO  Non Gated
# 54                     NJ                   Large          HMO  Non Gated
# 55                     NJ                   Large          HMO  Non Gated
# 59                     NJ                   Large          HMO  Non Gated
# 60                     NJ                   Large          HMO  Non Gated
# 61                     NJ                   Large          HMO  Non Gated
# 65                     NJ                   Large          HMO  Non Gated
# 66                     NJ                   Large          HMO  Non Gated
# 67                     NJ                   Large          HMO  Non Gated
#
#    Network Description EMERGENCY ROOM COPAY  \
# 3              Freedom                  NaN
# 4              Freedom                  NaN
# 5              Freedom                  NaN
# 9              Freedom                  NaN
# 10             Freedom                  NaN
# 11             Freedom                  NaN
# 15             Freedom                  NaN
# 16             Freedom                  NaN
# 17             Freedom                  NaN
# 21             Freedom                  NaN
# 22             Freedom                  NaN
# 23             Freedom                  NaN
# 27             Freedom                  NaN
# 28             Freedom                  NaN
# 29             Freedom                  NaN
# 33             Freedom                  NaN
# 34             Freedom                  NaN
# 35             Freedom                  NaN
# 36                 NaN                  NaN
# 37                 NaN                  NaN
# 41             Freedom                  NaN
# 42             Freedom                  NaN
# 43             Freedom                  NaN
# 47             Freedom                  NaN
# 48             Freedom                  NaN
# 49             Freedom                  NaN
# 53             Freedom                  NaN
# 54             Freedom                  NaN
# 55             Freedom                  NaN
# 59             Freedom                  NaN
# 60             Freedom                  NaN
# 61             Freedom                  NaN
# 65             Freedom                  NaN
# 66             Freedom                  NaN
# 67             Freedom                  NaN
#
#                              Hospital Cost Share  INN COINSURANCE  \
# 3   IP: 0 after deductible OP: 0 after deductible              92
# 4   IP: 0 after deductible OP: 0 after deductible              93
# 5   IP: 0 after deductible OP: 0 after deductible              94
# 9   IP: 0 after deductible OP: 0 after deductible              92
# 10  IP: 0 after deductible OP: 0 after deductible              93
# 11  IP: 0 after deductible OP: 0 after deductible              94
# 15  IP: 0 after deductible OP: 0 after deductible              92
# 16  IP: 0 after deductible OP: 0 after deductible              93
# 17  IP: 0 after deductible OP: 0 after deductible              94
# 21  IP: 0 after deductible OP: 0 after deductible              92
# 22  IP: 0 after deductible OP: 0 after deductible              93
# 23  IP: 0 after deductible OP: 0 after deductible              94
# 27  IP: 0 after deductible OP: 0 after deductible              92
# 28  IP: 0 after deductible OP: 0 after deductible              93
# 29  IP: 0 after deductible OP: 0 after deductible              94
# 33  IP: 0 after deductible OP: 0 after deductible              92
# 34  IP: 0 after deductible OP: 0 after deductible              93
# 35  IP: 0 after deductible OP: 0 after deductible              94
# 36                                            NaN             NaN
# 37                                            NaN             NaN
# 41  IP: 0 after deductible OP: 0 after deductible              92
# 42  IP: 0 after deductible OP: 0 after deductible              93
# 43  IP: 0 after deductible OP: 0 after deductible              94
# 47  IP: 0 after deductible OP: 0 after deductible              92
# 48  IP: 0 after deductible OP: 0 after deductible              93
# 49  IP: 0 after deductible OP: 0 after deductible              94
# 53  IP: 0 after deductible OP: 0 after deductible              92
# 54  IP: 0 after deductible OP: 0 after deductible              93
# 55  IP: 0 after deductible OP: 0 after deductible              94
# 59  IP: 0 after deductible OP: 0 after deductible              92
# 60  IP: 0 after deductible OP: 0 after deductible              93
# 61  IP: 0 after deductible OP: 0 after deductible              94
# 65  IP: 0 after deductible OP: 0 after deductible              92
# 66  IP: 0 after deductible OP: 0 after deductible              93
# 67  IP: 0 after deductible OP: 0 after deductible              94
#
#    OON COINSURANCE  \
# 3               92
# 4               93
# 5               94
# 9               92
# 10              93
# 11              94
# 15              92
# 16              93
# 17              94
# 21              92
# 22              93
# 23              94
# 27              92
# 28              93
# 29              94
# 33              92
# 34              93
# 35              94
# 36             NaN
# 37             NaN
# 41              92
# 42              93
# 43              94
# 47              92
# 48              93
# 49              94
# 53              92
# 54              93
# 55              94
# 59              92
# 60              93
# 61              94
# 65              92
# 66              93
# 67              94
#
#    List all three parts of the benefit: visit or dollar limit, INN cost share and OON cost share  \
# 3                               All radiology at 100%
# 4                                                 NaN
# 5                                                 NaN
# 9                               All radiology at 100%
# 10                                                NaN
# 11                                                NaN
# 15                              All radiology at 100%
# 16                                                NaN
# 17                                                NaN
# 21                              All radiology at 100%
# 22                                                NaN
# 23                                                NaN
# 27                              All radiology at 100%
# 28                                                NaN
# 29                                                NaN
# 33                              All radiology at 100%
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 41                              All radiology at 100%
# 42                                                NaN
# 43                                                NaN
# 47                              All radiology at 100%
# 48                                                NaN
# 49                                                NaN
# 53                              All radiology at 100%
# 54                                                NaN
# 55                                                NaN
# 59                              All radiology at 100%
# 60                                                NaN
# 61                                                NaN
# 65                              All radiology at 100%
# 66                                                NaN
# 67                                                NaN
#
#    PCP COPAY SPEC COPAY IND DEDUCTIBLE INN FAMILY DEDUCTIBLE INN  \
# 3         30         55               2500                  5002
# 4         30         60               2500                  5003
# 5          0          1               2500                  5004
# 9         30         55               2500                  5002
# 10        30         60               2500                  5003
# 11         0          1               2500                  5004
# 15        30         55               2500                  5002
# 16        30         60               2500                  5003
# 17         0          1               2500                  5004
# 21        30         55               2500                  5002
# 22        30         60               2500                  5003
# 23         0          1               2500                  5004
# 27        30         55               2500                  5002
# 28        30         60               2500                  5003
# 29         0          1               2500                  5004
# 33        30         55               2500                  5002
# 34        30         60               2500                  5003
# 35         0          1               2500                  5004
# 36       nan        nan                nan                   nan
# 37       nan        nan                nan                   nan
# 41        30         55               2500                  5002
# 42        30         60               2500                  5003
# 43         0          1               2500                  5004
# 47        30         55               2500                  5002
# 48        30         60               2500                  5003
# 49         0          1               2500                  5004
# 53        30         55               2500                  5002
# 54        30         60               2500                  5003
# 55         0          1               2500                  5004
# 59        30         55               2500                  5002
# 60        30         60               2500                  5003
# 61         0          1               2500                  5004
# 65        30         55               2500                  5002
# 66        30         60               2500                  5003
# 67         0          1               2500                  5004
#
#    IND IN Coinsurance Limit FAMILY IN Coinsurance Limit IND OOP INN  \
# 3                     32000                       50002       32000
# 4                     32000                       50003       32000
# 5                     32000                       50004       32000
# 9                     32000                       50002       32000
# 10                    32000                       50003       32000
# 11                    32000                       50004       32000
# 15                    32000                       50002       32000
# 16                    32000                       50003       32000
# 17                    32000                       50004       32000
# 21                    32000                       50002       32000
# 22                    32000                       50003       32000
# 23                    32000                       50004       32000
# 27                    32000                       50002       32000
# 28                    32000                       50003       32000
# 29                    32000                       50004       32000
# 33                    32000                       50002       32000
# 34                    32000                       50003       32000
# 35                    32000                       50004       32000
# 36                      nan                         nan         nan
# 37                      nan                         nan         nan
# 41                    32000                       50002       32000
# 42                    32000                       50003       32000
# 43                    32000                       50004       32000
# 47                    32000                       50002       32000
# 48                    32000                       50003       32000
# 49                    32000                       50004       32000
# 53                    32000                       50002       32000
# 54                    32000                       50003       32000
# 55                    32000                       50004       32000
# 59                    32000                       50002       32000
# 60                    32000                       50003       32000
# 61                    32000                       50004       32000
# 65                    32000                       50002       32000
# 66                    32000                       50003       32000
# 67                    32000                       50004       32000
#
#    FAMILY OOP INN IND DEDUCTIBLE OON FAMILY DEDUCTIBLE OON  \
# 3           50002               2500                  5002
# 4           50003               2500                  5003
# 5           50004               2500                  5004
# 9           50002               2500                  5002
# 10          50003               2500                  5003
# 11          50004               2500                  5004
# 15          50002               2500                  5002
# 16          50003               2500                  5003
# 17          50004               2500                  5004
# 21          50002               2500                  5002
# 22          50003               2500                  5003
# 23          50004               2500                  5004
# 27          50002               2500                  5002
# 28          50003               2500                  5003
# 29          50004               2500                  5004
# 33          50002               2500                  5002
# 34          50003               2500                  5003
# 35          50004               2500                  5004
# 36            nan                nan                   nan
# 37            nan                nan                   nan
# 41          50002               2500                  5002
# 42          50003               2500                  5003
# 43          50004               2500                  5004
# 47          50002               2500                  5002
# 48          50003               2500                  5003
# 49          50004               2500                  5004
# 53          50002               2500                  5002
# 54          50003               2500                  5003
# 55          50004               2500                  5004
# 59          50002               2500                  5002
# 60          50003               2500                  5003
# 61          50004               2500                  5004
# 65          50002               2500                  5002
# 66          50003               2500                  5003
# 67          50004               2500                  5004
#
#    IND OON Coinsurance Limit FAMILY OON Coinsurance Limit IND OOP OON  \
# 3                      32000                        50002       32000
# 4                      32000                        50003       32000
# 5                      32000                        50004       32000
# 9                      32000                        50002       32000
# 10                     32000                        50003       32000
# 11                     32000                        50004       32000
# 15                     32000                        50002       32000
# 16                     32000                        50003       32000
# 17                     32000                        50004       32000
# 21                     32000                        50002       32000
# 22                     32000                        50003       32000
# 23                     32000                        50004       32000
# 27                     32000                        50002       32000
# 28                     32000                        50003       32000
# 29                     32000                        50004       32000
# 33                     32000                        50002       32000
# 34                     32000                        50003       32000
# 35                     32000                        50004       32000
# 36                       nan                          nan         nan
# 37                       nan                          nan         nan
# 41                     32000                        50002       32000
# 42                     32000                        50003       32000
# 43                     32000                        50004       32000
# 47                     32000                        50002       32000
# 48                     32000                        50003       32000
# 49                     32000                        50004       32000
# 53                     32000                        50002       32000
# 54                     32000                        50003       32000
# 55                     32000                        50004       32000
# 59                     32000                        50002       32000
# 60                     32000                        50003       32000
# 61                     32000                        50004       32000
# 65                     32000                        50002       32000
# 66                     32000                        50003       32000
# 67                     32000                        50004       32000
#
#    FAMILY OOP OON IND Rx Copays (OV/Spec Copay must be listed above)  \
# 3           50002                                                 10
# 4           50003                                                nan
# 5           50004                                                nan
# 9           50002                                                 10
# 10          50003                                                nan
# 11          50004                                                nan
# 15          50002                                                 10
# 16          50003                                                nan
# 17          50004                                                nan
# 21          50002                                                 10
# 22          50003                                                nan
# 23          50004                                                nan
# 27          50002                                                 10
# 28          50003                                                nan
# 29          50004                                                nan
# 33          50002                                                 10
# 34          50003                                                nan
# 35          50004                                                nan
# 36            nan                                                nan
# 37            nan                                                nan
# 41          50002                                                 10
# 42          50003                                                nan
# 43          50004                                                nan
# 47          50002                                                 10
# 48          50003                                                nan
# 49          50004                                                nan
# 53          50002                                                 10
# 54          50003                                                nan
# 55          50004                                                nan
# 59          50002                                                 10
# 60          50003                                                nan
# 61          50004                                                nan
# 65          50002                                                 10
# 66          50003                                                nan
# 67          50004                                                nan
#
#    FAMILY Rx Copays (OV/Spec Copay must be listed above)
# 3                                                  25
# 4                                                 nan
# 5                                                 nan
# 9                                                  25
# 10                                                nan
# 11                                                nan
# 15                                                 25
# 16                                                nan
# 17                                                nan
# 21                                                 25
# 22                                                nan
# 23                                                nan
# 27                                                 25
# 28                                                nan
# 29                                                nan
# 33                                                 25
# 34                                                nan
# 35                                                nan
# 36                                                nan
# 37                                                nan
# 41                                                 25
# 42                                                nan
# 43                                                nan
# 47                                                 25
# 48                                                nan
# 49                                                nan
# 53                                                 25
# 54                                                nan
# 55                                                nan
# 59                                                 25
# 60                                                nan
# 61                                                nan
# 65                                                 25
# 66                                                nan
# 67                                                nan

# %% [markdown]
# ### Notes:
#
# - We need to consider cases where tables are arranged top to bottom. Presently the `separate_table` function only deals with tables arranged left to right
#
# - We need to include the logic to get rid additional/irrelevant texts present in the excel sheet above or below the tables
#
# - Some sheets contain 'Corrected Values', written next to the incorrect values which need to be considered.
